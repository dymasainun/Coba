# %% [markdown]
# <a href="https://colab.research.google.com/github/dymasainun/Coba/blob/master/GDG_Python_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo OCR with Colab
# ## GDG Surabaya Meetup - STTS Campus 6 July 2019
# By. Dr. Yosi Kristian, S.Kom., M.Kom.

# %% [markdown]
# Dalam colab ini didemokan pemanfaatan Tesseract untuk OCR tanpa menerapkan teknik-teknik dasar yang dibutuhkan untuk malakukan OCR secara manual: Thresholding, Connected Component Labeling, Template Matchning, DLL

# %%
# !apt install tesseract-ocr
# !apt install libtesseract-dev
# !pip install pyocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 1s (5,343 kB/s)
# ...

# %%
# !apt install tesseract-ocr-chi-sim
# !apt install tesseract-ocr-ind
# !apt install tesseract-ocr-jpn
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tesseract-ocr-chi-sim
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,636 kB of archives.
# After this operation, 2,484 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-chi-sim all 4.00~git24-0e00fe6-1.2 [1,636 kB]
# Fetched 1,636 kB in 1s (2,479 kB/s)
# Selecting previously unselected package tesseract-ocr-chi-sim.
# (Reading database ... 131100 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-chi-sim_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-chi-sim (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-chi-sim (4.00~git24-0e00fe6-1.2) ...
# ...

# %%
from PIL import Image
import sys
import pyocr
import pyocr.builders

# %%
tools = pyocr.get_available_tools()
tool = tools[0]

# %%
langs = tool.get_available_languages()
print("Available languages: %s" % ", ".join(langs))
lang = langs[0]
print("Will use lang '%s'" % (lang))
# Out:
# Available languages: ind, eng, osd, jpn, chi_sim
# Will use lang 'ind'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import cv2
import matplotlib.pyplot as plt
filename = "/content/gdrive/My Drive/ComputerVision/indo.jpg"
img = cv2.imread(filename)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(15,15))
plt.axis("off")
plt.imshow(img, cmap="gray")

# %%
txt = tool.image_to_string(
    Image.open(filename),
    lang="ind",
    builder=pyocr.builders.TextBuilder(tesseract_layout=6)
)
print(txt)
# Out:
# Metode yang penulis gunakan dalam menyusun skripsi ini adalah studi kepustakaan
# dengan bersumber pada satu buku pokok. Dari sumber pokok ini penulis mencoba
# menguraikan kembali pokok-pokok pikiran pengarang dengan membuat elaborasi,
# memperkaya dan mencari hubungan antara pokok-pokok bahasan dengan beberapa acuan
# yang relevan. E

# %%
filename = "/content/gdrive/My Drive/ComputerVision/BCA-1.jpg"
img = cv2.imread(filename)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.axis("off")
plt.imshow(img)

# %%
txt = tool.image_to_string(
    Image.open(filename),
    lang="ind",
    builder=pyocr.builders.TextBuilder(tesseract_layout=6)
)
print(txt)
# Out:
# BB
# ?
#
# xx ATM BCA xx
#
# 23/05/17 13:18:55
#
# 0870-SPBU JAGAKARSA 2
#
# NO. URUT : 562
#
# TRANSFER
# : KE BANK : 002 - BRI
#
# KE REK. : 053801005962539
#
# NAMA : ROHMATULLOH
#
# JUMLAH — : RP 300,000.00
#
# UNTUK KENYAMANAN ANDA
# LIMIT TRANSAKSI| KARTU AKAN
# DITINGKATKAN (WWW.BCA.Co.1ID)
